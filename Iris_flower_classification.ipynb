# %% [markdown]
# <a href="https://colab.research.google.com/github/Priya-gawhane/Machine-learning-prediction-Models-Projects/blob/main/Iris_flower_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris

# %% [markdown]
# Data Collection and preprocessesing

# %%
dataset = pd.read_csv('/content/training.1600000.processed.noemoticon.csv', header = None, delimiter="\t", quoting=3, error_bad_lines=False, encoding='utf-8')
# Out:
# <ipython-input-43-7164e3872f16>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   dataset = pd.read_csv('/content/training.1600000.processed.noemoticon.csv', header = None, delimiter="\t", quoting=3, error_bad_lines=False, encoding='utf-8')
# Skipping line 5312: expected 1 fields, saw 2
# Skipping line 16550: expected 1 fields, saw 2
# Skipping line 19852: expected 1 fields, saw 2
# Skipping line 20232: expected 1 fields, saw 2
# Skipping line 29309: expected 1 fields, saw 2
# Skipping line 34490: expected 1 fields, saw 2
# Skipping line 35376: expected 1 fields, saw 2
# Skipping line 56786: expected 1 fields, saw 2
# Skipping line 85615: expected 1 fields, saw 2
# Skipping line 92196: expected 1 fields, saw 2
# Skipping line 99542: expected 1 fields, saw 2
# Skipping line 104733: expected 1 fields, saw 2
# Skipping line 108691: expected 1 fields, saw 2
# ...

# %%
dataset.head(10)
# Out:
#                                                    0
# 0  "0","1467810369","Mon Apr 06 22:19:45 PDT 2009...
# 1  "0","1467810672","Mon Apr 06 22:19:49 PDT 2009...
# 2  "0","1467810917","Mon Apr 06 22:19:53 PDT 2009...
# 3  "0","1467811184","Mon Apr 06 22:19:57 PDT 2009...
# 4  "0","1467811193","Mon Apr 06 22:19:57 PDT 2009...
# 5  "0","1467811372","Mon Apr 06 22:20:00 PDT 2009...
# 6  "0","1467811592","Mon Apr 06 22:20:03 PDT 2009...
# 7  "0","1467811594","Mon Apr 06 22:20:03 PDT 2009...
# 8  "0","1467811795","Mon Apr 06 22:20:05 PDT 2009...
# 9  "0","1467812025","Mon Apr 06 22:20:09 PDT 2009...
